# %% [markdown]
# <p style="text-align: center"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data from file

# %%
df = pd.read_csv("us_citizens_data.csv")

# %% [markdown]
# # Try to understand what the data looks like? What are types of the features? Are there any missing values? Do I need to eliminate some features?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   31759.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.082843   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.576172   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Look at the value counts of columns that have object datatype and replace '?' like values with 'Unknown' word.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
groupss = df.columns[df.dtypes == 'object']
groupss
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'salary'],
#       dtype='object')

# %%
top = df[df.columns[df.dtypes == 'object']].mode()
top.iloc[0]
# Out:
# workclass                    Private
# education                    HS-grad
# marital-status    Married-civ-spouse
# occupation            Prof-specialty
# relationship                 Husband
# race                           White
# sex                             Male
# native-country         United-States
# salary                         <=50K
# Name: 0, dtype: object

# %%
count = df[df.columns[df.dtypes == 'object']].count()
count
# Out:
# workclass         32561
# education         32561
# marital-status    32561
# occupation        32561
# relationship      27493
# race              32561
# sex               32561
# native-country    32561
# salary            32561
# dtype: int64

# %%
unique = df[df.columns[df.dtypes == 'object']].nunique()
unique
# Out:
# workclass          9
# education         16
# marital-status     7
# occupation        15
# relationship       5
# race               5
# sex                2
# native-country    42
# salary             2
# dtype: int64

# %%
data = {col: len(df[df[col] == top.loc[0][col]]) for col in groupss}
freq = pd.Series(data)
freq
# Out:
# workclass         22696
# education         10501
# marital-status    14976
# occupation         4140
# relationship      13193
# race              27816
# sex               21790
# native-country    29170
# salary            24720
# dtype: int64

# %%
res1 = pd.concat([count, unique, top.iloc[0], freq], axis=1).T

# %%
res1.index = ['count', 'unique', 'top', 'freq']

# %%
df.select_dtypes(include='object').describe()
# df.describe(include=['object'])
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        27493
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
res1
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        27493
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
df['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df[df['workclass'] == '?']
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 27      54         ?  180211  Some-college           10.0
# 61      32         ?  293936       7th-8th            4.0
# 69      25         ?  200681  Some-college           10.0
# 77      67         ?  212759          10th            6.0
# 106     17         ?  304873          10th            6.0
# ...    ...       ...     ...           ...            ...
# 32530   35         ?  320084     Bachelors           13.0
# 32531   30         ?   33811     Bachelors           13.0
# 32539   71         ?  287372     Doctorate            NaN
# 32541   41         ?  202822       HS-grad            9.0
# 32542   72         ?  129912       HS-grad            9.0
#
#               marital-status occupation   relationship                race  \
# 27        Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent          ?  Not-in-family               White
# ...

# %%
df['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df[df.isin(['?'])].any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country     True
# salary            False
# dtype: bool

# %%
df[df['workclass'] == '?'].replace(to_replace = '?', value = 'Unknown')
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 27      54   Unknown  180211  Some-college           10.0
# 61      32   Unknown  293936       7th-8th            4.0
# 69      25   Unknown  200681  Some-college           10.0
# 77      67   Unknown  212759          10th            6.0
# 106     17   Unknown  304873          10th            6.0
# ...    ...       ...     ...           ...            ...
# 32530   35   Unknown  320084     Bachelors           13.0
# 32531   30   Unknown   33811     Bachelors           13.0
# 32539   71   Unknown  287372     Doctorate            NaN
# 32541   41   Unknown  202822       HS-grad            9.0
# 32542   72   Unknown  129912       HS-grad            9.0
#
#               marital-status occupation   relationship                race  \
# 27        Married-civ-spouse    Unknown        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent    Unknown  Not-in-family               White
# ...

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Do education and education_num columns hold similar information? If so drop the appropriate choice between them.

# %%
df['education']
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
#             ...
# 32556    Assoc-acdm
# 32557       HS-grad
# 32558       HS-grad
# 32559       HS-grad
# 32560       HS-grad
# Name: education, Length: 32561, dtype: object

# %%
df['education-num']
# Out:
# 0        13.0
# 1        13.0
# 2         9.0
# 3         7.0
# 4        13.0
#          ...
# 32556    12.0
# 32557     9.0
# 32558     9.0
# 32559     9.0
# 32560     9.0
# Name: education-num, Length: 32561, dtype: float64

# %%
df[['education', 'education-num']].value_counts().sort_index()
# Out:
# education     education-num
# 10th          6.0                916
# 11th          7.0               1146
# 12th          8.0                424
# 1st-4th       2.0                161
# 5th-6th       3.0                330
# 7th-8th       4.0                631
# 9th           5.0                503
# Assoc-acdm    12.0              1044
# Assoc-voc     11.0              1343
# Bachelors     13.0              5247
# Doctorate     16.0               405
# HS-grad       9.0              10215
# Masters       14.0              1687
# Preschool     1.0                 50
# Prof-school   15.0               559
# Some-college  10.0              7098
# dtype: int64

# %%
df['education-num'].value_counts()
# Out:
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: education-num, dtype: int64

# %%
df.drop(columns='education-num', inplace=True)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Take a look at correlation between variables and also see if there are some outliers in any of the columns.

# %%
df.corr()
# Out:
#                      age    fnlwgt  education-num  capital-gain  capital-loss  \
# age             1.000000 -0.076646       0.035791      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043711      0.000432     -0.010252
# education-num   0.035791 -0.043711       1.000000      0.123682      0.079795
# capital-gain    0.077674  0.000432       0.123682      1.000000     -0.031615
# capital-loss    0.057775 -0.010252       0.079795     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768       0.147748      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education-num         0.147748
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
df[['age', 'fnlwgt', 'capital-gain', 'capital-loss', 'hours-per-week']].corr()
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076646      0.077674      0.057775        0.068756
# fnlwgt         -0.076646  1.000000      0.000432     -0.010252       -0.018768
# capital-gain    0.077674  0.000432      1.000000     -0.031615        0.078409
# capital-loss    0.057775 -0.010252     -0.031615      1.000000        0.054256
# hours-per-week  0.068756 -0.018768      0.078409      0.054256        1.000000

# %%
df[['age', 'fnlwgt', 'capital-gain', 'capital-loss', 'hours-per-week']].describe()
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  32561.000000  32561.000000    32561.000000
# mean      38.581647  1.897784e+05   1077.648844     87.303830       40.437456
# std       13.640433  1.055500e+05   7385.292085    402.960219       12.347429
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.178270e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.783560e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.370510e+05      0.000000      0.000000       45.000000
# max       90.000000  1.484705e+06  99999.000000   4356.000000       99.000000

# %%
#age column
IQR = df['age'].quantile(0.75) - df['age'].quantile(0.25)
IQR
# Out:
# 20.0

# %%
upper_lim = IQR * 1.5 + df['age'].quantile(0.75)
upper_lim
# Out:
# 78.0

# %%
df[df["age"] >= upper_lim]["age"].value_counts()
# Out:
# 90    43
# 78    23
# 80    22
# 79    22
# 81    20
# 82    12
# 84    10
# 83     6
# 88     3
# 85     3
# 87     1
# 86     1
# Name: age, dtype: int64

# %%
fig, ax = plt.subplots(2,3,figsize=(20,7))
x = 0
y = 0
for column in df.select_dtypes('number').columns:
    
    df[column].plot(kind = "box", ax = ax[x,y])
    if y < 2:
        y += 1
    else:
        x += 1
        y = 0

# %%
df[(df["hours-per-week"] == 99)].sample(10)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 10468   44  Self-emp-not-inc  277783       Masters           14.0
# 5376    43           Private   86750     Assoc-voc           11.0
# 24483   39      Self-emp-inc  124685       Masters           14.0
# 13558   38           Private  191103   Prof-school           15.0
# 30992   40      Self-emp-inc  104235       Masters           14.0
# 6898    53  Self-emp-not-inc  151159          10th            6.0
# 20036   61      Self-emp-inc  102191       Masters           14.0
# 4086    50                 ?  174964          10th            6.0
# 27764   38  Self-emp-not-inc  152621     Bachelors           13.0
# 8393    50      Self-emp-inc  119099  Some-college           10.0
#
#               marital-status        occupation   relationship  \
# 10468          Never-married   Farming-fishing            NaN
# 5376      Married-civ-spouse      Craft-repair        Husband
# ...

# %%
#hours per week column
IQR = df['hours-per-week'].quantile(0.75) - df['hours-per-week'].quantile(0.25)
IQR
# Out:
# 5.0

# %%
upper_lim2 = IQR * 1.5 + df['hours-per-week'].quantile(0.75)
upper_lim2
# Out:
# 52.5

# %%
df.replace(to_replace = '?', value = 'Unknown', inplace=True)

# %%
filt = (df['age'] >= upper_lim) & (df['hours-per-week'] >= upper_lim2)
outliers = df[filt]
outliers
# Out:
#        age     workclass  fnlwgt     education  education-num  \
# 3777    80       Private   87518  Some-college           10.0
# 5370    90     Local-gov  227796       Masters           14.0
# 7481    83       Private  195507       HS-grad            9.0
# 7720    84       Private  241065       Masters           14.0
# 8806    90       Private   87372   Prof-school           15.0
# 10546   78       Unknown   33186       7th-8th            4.0
# 11996   90       Private   40388     Bachelors           13.0
# 12830   81       Private  201398       Masters           14.0
# 15356   90       Private   90523       HS-grad            9.0
# 24395   83  Self-emp-inc  153183     Bachelors           13.0
#
#            marital-status        occupation   relationship   race   sex  \
# 3777        Never-married    Prof-specialty  Not-in-family  White  Male
# 5370   Married-civ-spouse   Exec-managerial        Husband  White  Male
# ...

# %% [markdown]
# # After looking at the outliers you can drop the rows which actually does not make any sense.
# ** Hint: You can check age and hours per week columns. **

# %%
drop_index = outliers.index

# %%
df_without_outliers = df.drop(drop_index)

# %%
df_without_outliers
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df_without_outliers.loc[filt]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, education-num, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %% [markdown]
# # Impute missing values in relationship column with 'Unmarried'. Also replace 'Not-in-family','Other-relative' values in this column with 'Unmarried'?

# %%
df_without_outliers['relationship'].value_counts()
# Out:
# Husband           13189
# Not-in-family      8301
# Unmarried          3444
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df_without_outliers['relationship'].value_counts(dropna=False)
# Out:
# Husband           13189
# Not-in-family      8301
# NaN                5068
# Unmarried          3444
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df_without_outliers['relationship'].fillna('Unmarried', inplace=True)

# %%
df_without_outliers['relationship'].replace(to_replace=['Not-in-family', 'Other-relative'], 
                                            value='Unmarried', inplace=True)

# %%
df_without_outliers.relationship.value_counts()
# Out:
# Unmarried    17794
# Husband      13189
# Wife          1568
# Name: relationship, dtype: int64

# %% [markdown]
# ---
# # How many of each race are represented in this dataset?
# ---

# %%
race_count = df_without_outliers['race'].value_counts()
race_count
# Out:
# White                 27806
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
race_count.sort_values().plot.barh();

# %% [markdown]
# ---
# # What is the average age of men/women?
# ---

# %%
average_age_men = df_without_outliers[df_without_outliers['sex'] == 'Male'].age.mean()
average_age_men
# Out:
# 39.41267217630854

# %%
df_without_outliers.loc[df_without_outliers['sex'] == 'Male', 'age'].mean()
# Out:
# 39.41267217630854

# %%
round(average_age_men,1)
# Out:
# 39.4

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Male", "age"].value_counts().sort_index().plot.bar();

# %%
average_age_women = df_without_outliers[df_without_outliers['sex'] == 'Female'].age.mean()
average_age_women
# Out:
# 36.85823043357163

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Female", "age"].value_counts().sort_index().plot.bar();

# %% [markdown]
# ---
# # What is the percentage of people who have a Bachelor's degree?
# ---

# %%
df_without_outliers['education'].value_counts().sort_index()
# Out:
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           645
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5353
# Doctorate         413
# HS-grad         10499
# Masters          1720
# Preschool          51
# Prof-school       575
# Some-college     7290
# Name: education, dtype: int64

# %%
df_without_outliers['education'].value_counts().sort_values(ascending=False)
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
upper = len(df_without_outliers[df_without_outliers['education'] == 'Bachelors'])

lower = len(df_without_outliers['education'])

percentage_bachelors = upper / lower * 100

percentage_bachelors
# Out:
# 16.444963288378236

# %%
df_without_outliers["education"].value_counts(normalize=True)
# Out:
# HS-grad         0.322540
# Some-college    0.223956
# Bachelors       0.164450
# Masters         0.052840
# Assoc-voc       0.042456
# 11th            0.036097
# Assoc-acdm      0.032779
# 10th            0.028663
# 7th-8th         0.019815
# Prof-school     0.017665
# 9th             0.015791
# 12th            0.013302
# Doctorate       0.012688
# 5th-6th         0.010230
# 1st-4th         0.005161
# Preschool       0.001567
# Name: education, dtype: float64

# %%
percentage_bachelors = df_without_outliers["education"].value_counts(normalize=True).loc["Bachelors"]*100
round(percentage_bachelors,1)
# Out:
# 16.4

# %%
print(f"The percentage of people who have a Bachelor's degree : %{round(percentage_bachelors,1)}")
# Out:
# The percentage of people who have a Bachelor's degree : %16.4

# %% [markdown]
# ---
# # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# ---

# %%
df_without_outliers['salary'].value_counts()
# Out:
# <=50K    24713
# >50K      7838
# Name: salary, dtype: int64

# %%
df_without_outliers['education'].value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
higher_education = df_without_outliers['education'].isin(['Bachelors', 'Masters', 'Doctorate'])
higher_education
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32551, dtype: bool

# %%
df_high_edu = df_without_outliers[higher_education]
df_high_edu
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516  Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 4       28           Private  338409  Bachelors  Married-civ-spouse
# 5       37           Private  284582    Masters  Married-civ-spouse
# 8       31           Private   45781    Masters       Never-married
# ...    ...               ...     ...        ...                 ...
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32544   31           Private  199655    Masters            Divorced
# 32553   32           Private  116138    Masters       Never-married
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
df_high_edu[df_high_edu['salary'] == '>50K']
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 8       31           Private   45781    Masters       Never-married
# 9       42           Private  159449  Bachelors  Married-civ-spouse
# 11      30         State-gov  141297  Bachelors  Married-civ-spouse
# 19      43  Self-emp-not-inc  292175    Masters            Divorced
# 20      40           Private  193524  Doctorate  Married-civ-spouse
# ...    ...               ...     ...        ...                 ...
# 32533   54           Private  337992  Bachelors  Married-civ-spouse
# 32536   34           Private  160216  Bachelors       Never-married
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
count = len(df_high_edu[df_high_edu['salary'] == '>50K'])

# %%
perc_high_edu = count / len(df_without_outliers)

# %%
perc_high_edu
# Out:
# 0.10703204202635863

# %%
print(f"Percentage of people with advanced education make more than 50K : {round(perc_high_edu * 100, 2)}")
# Out:
# Percentage of people with advanced education make more than 50K : 10.7

# %% [markdown]
# ---
# # What percentage of people without advanced education make more than 50K?
# ---

# %%
df_low_edu = df_without_outliers[~higher_education]
df_low_edu
# Out:
#        age         workclass  fnlwgt     education         marital-status  \
# 2       38           Private  215646       HS-grad               Divorced
# 3       53           Private  234721          11th     Married-civ-spouse
# 6       49           Private  160187           9th  Married-spouse-absent
# 7       52  Self-emp-not-inc  209642       HS-grad     Married-civ-spouse
# 10      37           Private  280464  Some-college     Married-civ-spouse
# ...    ...               ...     ...           ...                    ...
# 32556   27           Private  257302    Assoc-acdm     Married-civ-spouse
# 32557   40           Private  154374       HS-grad     Married-civ-spouse
# 32558   58           Private  151910       HS-grad                Widowed
# 32559   22           Private  201490       HS-grad          Never-married
# 32560   52      Self-emp-inc  287927       HS-grad     Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# ...

# %%
df_low_edu[df_low_edu['salary'] == '>50K']
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 7       52  Self-emp-not-inc  209642       HS-grad  Married-civ-spouse
# 10      37           Private  280464  Some-college  Married-civ-spouse
# 14      40           Private  121772     Assoc-voc  Married-civ-spouse
# 27      54           Unknown  180211  Some-college  Married-civ-spouse
# 38      31           Private   84154  Some-college  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 32518   57         Local-gov  110417       HS-grad  Married-civ-spouse
# 32519   46           Private  364548  Some-college  Married-civ-spouse
# 32545   39         Local-gov  111499    Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374       HS-grad  Married-civ-spouse
# 32560   52      Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship                race     sex  \
# ...

# %%
count = len(df_low_edu[df_low_edu['salary'] == '>50K'])

# %%
count
# Out:
# 4354

# %%
perc_low_edu = count / len(df_without_outliers)
perc_low_edu
# Out:
# 0.13375933151055266

# %%
print(f"Percentage of people without advanced education make more than 50K : {round(perc_low_edu * 100 ,2)}")
# Out:
# Percentage of people without advanced education make more than 50K : 13.38

# %%
if perc_high_edu > perc_low_edu :
    print("More education more money!")
else:
    print("Education has no clear effet on salary. You should investigate some other features also.")
# Out:
# Education has no clear effet on salary. You should investigate some other features also.

# %% [markdown]
# ---
# # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
# ---

# %%
df_without_outliers['hours-per-week'].value_counts()
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1471
# 35     1297
#       ...
# 92        1
# 94        1
# 87        1
# 74        1
# 82        1
# Name: hours-per-week, Length: 94, dtype: int64

# %%
lazy_riches = (df_without_outliers['hours-per-week'] == df_without_outliers
               ['hours-per-week'].min()) & (df_without_outliers['salary'] == '>50K')
lazy_riches
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32551, dtype: bool

# %%
df_without_outliers[lazy_riches]
# Out:
#        age  workclass  fnlwgt  education      marital-status      occupation  \
# 189     58  State-gov  109567  Doctorate  Married-civ-spouse  Prof-specialty
# 20072   65    Unknown   76043    HS-grad  Married-civ-spouse         Unknown
#
#       relationship   race   sex  capital-gain  capital-loss  hours-per-week  \
# 189        Husband  White  Male             0             0               1
# 20072      Husband  White  Male             0             0               1
#
#       native-country salary
# 189    United-States   >50K
# 20072  United-States   >50K

# %%
num_lazy_riches = len(df_without_outliers[lazy_riches])
num_lazy_riches
# Out:
# 2

# %%
num_min_workers = len(df_without_outliers[(df_without_outliers['hours-per-week'] == df_without_outliers
                                       ['hours-per-week'].min())])
num_min_workers
# Out:
# 20

# %%
print (f"Percentage of the people who work the minimum number of hours per week have a salary of >50K : % {round(num_lazy_riches/num_min_workers*100)}")
# Out:
# Percentage of the people who work the minimum number of hours per week have a salary of >50K : % 10

# %% [markdown]
#  ---
#  # What country has the highest percentage of people that earn >50K?
#  ---

# %%
country_salary_df = df_without_outliers.groupby('native-country').count()[['salary']]
country_salary_df
# Out:
#                             salary
# native-country
# Cambodia                        19
# Canada                         121
# China                           75
# Columbia                        59
# Cuba                            95
# Dominican-Republic              70
# Ecuador                         28
# El-Salvador                    106
# England                         90
# France                          29
# Germany                        137
# Greece                          29
# Guatemala                       64
# Haiti                           44
# Holand-Netherlands               1
# Honduras                        13
# Hong                            20
# Hungary                         13
# India                          100
# Iran                            43
# Ireland                         24
# Italy                           73
# Jamaica                         81
# Japan                           62
# Laos                            18
# ...

# %%
country_salary_df_riches = df_without_outliers[df_without_outliers
                        ['salary'] == '>50K'].groupby('native-country').count()[['salary']]
country_salary_df_riches
# Out:
#                     salary
# native-country
# Cambodia                 7
# Canada                  39
# China                   20
# Columbia                 2
# Cuba                    25
# Dominican-Republic       2
# Ecuador                  4
# El-Salvador              9
# England                 30
# France                  12
# Germany                 44
# Greece                   8
# Guatemala                3
# Haiti                    4
# Honduras                 1
# Hong                     6
# Hungary                  3
# India                   40
# Iran                    18
# Ireland                  5
# Italy                   25
# Jamaica                 10
# Japan                   24
# Laos                     2
# Mexico                  33
# Nicaragua                2
# Peru                     2
# Philippines             61
# Poland                  12
# Portugal                 4
# Puerto-Rico             12
# Scotland                 3
# ...

# %%
rich_per_country = (country_salary_df_riches / country_salary_df).sort_values('salary')
rich_per_country
# Out:
#                               salary
# native-country
# Dominican-Republic          0.028571
# Columbia                    0.033898
# Guatemala                   0.046875
# Mexico                      0.051322
# Nicaragua                   0.058824
# Peru                        0.064516
# Vietnam                     0.074627
# Honduras                    0.076923
# El-Salvador                 0.084906
# Haiti                       0.090909
# Trinadad&Tobago             0.105263
# Puerto-Rico                 0.105263
# Portugal                    0.108108
# Laos                        0.111111
# Jamaica                     0.123457
# Ecuador                     0.142857
# Thailand                    0.166667
# Poland                      0.200000
# South                       0.200000
# Ireland                     0.208333
# Hungary                     0.230769
# United-States               0.245808
# Scotland                    0.250000
# Unknown                     0.250859
# ...

# %%
rich_per_country[['salary']].loc[['Iran']]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
rich_per_country.salary.sort_values(ascending=False).iloc[rich_per_country[['salary']].max()]
# Out:
# native-country
# Iran    0.418605
# Name: salary, dtype: float64

# %%
rich_per_country.iloc[[-3]]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
plt.figure(figsize=(14,7))
df.loc[df["salary"] == ">50K", "native-country"].value_counts().plot(kind="bar");

# %%
plt.figure(figsize=(12,6))
df.loc[((df["native-country"] == "Iran")), "salary"].value_counts().plot.bar();

# %% [markdown]
# ---
# # Identify the most popular occupation for those who earn >50K in India.
# ---

# %%
top_IN_occupation = (df_without_outliers['native-country'] == 'India') & (df_without_outliers['salary'] == '>50K')
top_IN_occupation
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32551, dtype: bool

# %%
df_without_outliers[top_IN_occupation]
# Out:
#        age         workclass  fnlwgt    education         marital-status  \
# 11      30         State-gov  141297    Bachelors     Married-civ-spouse
# 968     48           Private  164966    Bachelors     Married-civ-spouse
# 1327    52           Private  168381      HS-grad                Widowed
# 7258    42         State-gov  102343  Prof-school     Married-civ-spouse
# 7285    54         State-gov   93449      Masters     Married-civ-spouse
# 8124    36           Private  172104  Prof-school          Never-married
# 9939    43       Federal-gov  325706  Prof-school     Married-civ-spouse
# 10590   35           Private   98283  Prof-school          Never-married
# 10661   59           Private  122283  Prof-school     Married-civ-spouse
# 10736   30           Private  243190  Prof-school     Married-civ-spouse
# 11260   54           Private  225599      Masters     Married-civ-spouse
# 11384   34           Private   98283  Prof-school          Never-married
# ...

# %%
df_without_outliers[top_IN_occupation]['occupation'].value_counts()
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Adm-clerical         1
# Sales                1
# Transport-moving     1
# Name: occupation, dtype: int64

# %%
df_without_outliers[top_IN_occupation]['occupation'].iloc[0]
# Out:
# 'Prof-specialty'

# %%
a = df_without_outliers[top_IN_occupation]['occupation'].mode()[0]
a
# Out:
# 'Prof-specialty'

# %%
print(f"{a} the most popular occupation for those who earn >50K in India.")
# Out:
# Prof-specialty the most popular occupation for those who earn >50K in India.

# %% [markdown]
# ----
# ---
