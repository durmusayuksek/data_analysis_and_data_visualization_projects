# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://doc-04-3g-docs.googleusercontent.com/docs/securesc/ofpp6990m5o5ef22cu20c3n1mqts74pe/r6qc2ihej1935v0e4mo4g0ab7vkjb10j/1635369525000/04636354074472831662/05717713031668214889Z/1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV?nonce=auvi0hnnie49k&user=05717713031668214889Z&hash=s8k6jl6mjm3gtpre48mfaplq6vp0hphj" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# <div style='color : pink;'>
# <p style='color : blue;'> Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.</p>
#
# <p style='color : blue;'> The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.</p>
#
# <p style='color : blue;'> This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.</p>
# </div>

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df = pd.read_csv('bike_sharing_data.csv')

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
ax = sns.countplot(x='season', data=df)
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.25, p.get_height()+50));

# %%
sns.countplot(x='is_holiday', data=df);

# %%
sns.countplot(x='is_weekend', data=df);

# %%
sns.countplot(x='weather_code', data=df);

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
df.dtypes
# Out:
# timestamp        object
# cnt               int64
# t1              float64
# t2              float64
# hum             float64
# wind_speed      float64
# weather_code    float64
# is_holiday      float64
# is_weekend      float64
# season          float64
# dtype: object

# %%
df.timestamp = df.timestamp.transform(lambda x: pd.to_datetime(x))
# df.timestamp = pd.to_datetime(df.timestamp)

# %%
df.set_index('timestamp', drop=True, inplace=True)

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0
# 2015-01-04 01:00:00         0.0         1.0     3.0
# 2015-01-04 02:00:00         0.0         1.0     3.0
# 2015-01-04 03:00:00         0.0         1.0     3.0
# 2015-01-04 04:00:00         0.0         1.0     3.0

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df['year_month'] = df.index.map(lambda x: x.strftime('%Y-%m'))
df['year'] = df.index.map(lambda x: int(x.strftime('%Y')))
df['month'] = df.index.map(lambda x: int(x.strftime('%-m')))
df['day_of_month'] = df.index.map(lambda x: int(x.strftime('%-d')))
df['day_of_week'] = df.index.map(lambda x: int(x.strftime('%u')) - 1)
df['hour'] = df.index.map(lambda x: int(x.strftime('%-H')))

# df["year-month"] = df.index.strftime("%Y-%m")
# df["year"] =  df.index.year
# df["month"] =  df.index.month
# df["day_of_month"] =  df.index.day
# df["day_of_week"] =  df.index.dayofweek
# df["hour"] = df.index.hour

# %%
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#                      is_holiday  is_weekend  season year_month  year  month  \
# timestamp
# 2015-01-04 00:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 01:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 02:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 03:00:00         0.0         1.0     3.0    2015-01  2015      1
# 2015-01-04 04:00:00         0.0         1.0     3.0    2015-01  2015      1
#
#                      day_of_month  day_of_week  hour
# timestamp
# ...

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), cmap='RdBu', annot=True);

# %%
correlation = df.corr()
a = pd.DataFrame(correlation['cnt'].sort_values(ascending=False))

# %%
plt.figure(figsize=(2,7))
sns.heatmap(a, annot=True, cmap='RdBu', vmin=-1, vmax=1);

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
plt.figure(figsize=(10,6))
plt.barh(y=a.index[::-1], width=a['cnt'][::-1], height=0.5);

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=df.index, y=df.cnt);

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
plt.figure(figsize=(17,4))
sns.lineplot(x=df.year_month.value_counts().index, 
             y=df.groupby('year_month').cnt.sum().values, ci=None)
plt.xticks(rotation='vertical');

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x=df.month, y=df.cnt);

# %%
plt.figure(figsize=(15,5))
sns.pointplot(x=df.month, y=df.cnt);

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=df.month, y=df.cnt);

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
plt.figure(figsize=(17,4))
sns.lineplot(x=df.hour, y=df.cnt, hue=df.is_holiday);

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=df.hour, y=df.cnt, hue=df.season);

# %%
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(18,15))
sns.pointplot(x=df.hour, y=df.cnt, ax=ax[0])
sns.pointplot(x=df.hour, y=df.cnt, ax=ax[1], hue=df.is_holiday)
sns.pointplot(x=df.hour, y=df.cnt, ax=ax[2], hue=df.is_weekend)
sns.pointplot(x=df.hour, y=df.cnt, ax=ax[3], hue=df.season);

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
plt.figure(figsize=(7,4))
sns.barplot(x=df.day_of_week, y=df.cnt, hue=df.is_weekend);

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(15,8))
sns.pointplot(x=df.day_of_week, y=df.cnt, ax=ax[0])
sns.pointplot(x=df.day_of_week, y=df.cnt, hue=df.season, ax=ax[1]);

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x=df.day_of_month, y=df.cnt);
df.groupby('day_of_month')[['cnt']].mean().T.style.format('{0:.0f}')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=df.year, y=df.cnt);

# %%
b = df[df.is_holiday.isin([1])]

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=b.season, y=b.cnt);

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
df.is_weekend.value_counts()
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
x = df.is_weekend.value_counts()

# %%
plt.pie(x=x, labels= ['weekday', 'weekend'], autopct='%0.1f%%', radius=1.25);

# %%
t = df.is_weekend.value_counts().sum()
g = df.is_weekend.value_counts()

# %%
plt.figure(figsize=(7,5))
sns.countplot(x=df.is_weekend)
for i in range(len(df.is_weekend.value_counts())):
    new = f'%{round((g[i]/t) * 100, 1)} - {g[i]}'
    plt.text(x=i, y=g[i] + 50, s = new, ha='center', size=13);

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
sns.countplot(x=df.weather_code);

# %%
sns.catplot(x='weather_code', data=df, col='season', kind='count');

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
